# %% [markdown]
# # pandas part 1

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("./Data/services.csv")

# %% [markdown]
# Here `df` is a data frame that is a data structure in python. A DataFrame is a two-dimensional, size-mutable, and heterogeneous tabular data structure provided by the pandas library. It's similar to a spreadsheet or SQL table, where data is organized into rows and columns. DataFrames are commonly used for data manipulation, analysis, and cleaning tasks.

# %%
# display the first few rows of a DataFrame.
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %% [markdown]
# - The code snippet `df.head()` is a call to the `head()` method of the DataFrame object `df`. This method is commonly used in Pandas to display the first few rows of a DataFrame. It's a way to quickly inspect the data in the DataFrame without printing the entire dataset.
#
# - The output you provided is the result of calling `df.head()`, which displays the first 5 rows of the DataFrame. Each row represents a record, and each column represents a specific attribute or feature of that record. The columns are labeled with various attributes such as `id`, `location_id`, `program_id`, `accepted_payments`, `alternate_name`, `application_process`, `audiene`, `description`, `eligibilty`, `email`, `fee`, `funding_source`, `interpretation_service`, `keywords`, `language`, `name`, `required_document`, `service_areas`, `status`, `wait_time`, `website` and `taxonomy_ids`.
#
# - The actual data for each record is shown below these column labels. For example, the first record has values like 1, 1, NaN, NaN, NaN, Walk in or apply by phone., and so on, for each of the columns. These values correspond to the first 5 records in the DataFrame.
#
# - This output is useful for quickly getting an overview of the structure and contents of the DataFrame without having to look at the entire dataset, which can be especially helpful when dealing with large datasets.

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
# display the last few rows of a DataFrame.
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# extracting the 'status' column from the DataFrame df
df['status']
# Out:
# 0       active
# 1       active
# 2       active
# 3       active
# 4       active
# 5       active
# 6       active
# 7       active
# 8       active
# 9       active
# 10      active
# 11      active
# 12      active
# 13      active
# 14      active
# 15      active
# 16      active
# 17      active
# 18      active
# 19     defunct
# 20    inactive
# 21      active
# 22      active
# Name: status, dtype: object

# %%
# The column 'status' is a Pandas Series object within the DataFrame df. 
# A Pandas Series is a one-dimensional labeled array capable of holding data of various types. 
# It's a fundamental data structure in Pandas used to represent a single column or row of data.
type(df['status'])
# Out:
# pandas.core.series.Series

# %%
list(df['status'])
# Out:
# ['active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'defunct',
#  'inactive',
#  'active',
#  'active']

# %%
df[['status']]
# Out:
#       status
# 0     active
# 1     active
# 2     active
# 3     active
# 4     active
# 5     active
# 6     active
# 7     active
# 8     active
# 9     active
# 10    active
# 11    active
# 12    active
# 13    active
# 14    active
# 15    active
# 16    active
# 17    active
# 18    active
# 19   defunct
# 20  inactive
# 21    active
# 22    active

# %%
# The double square brackets [['status']] are used to select a specific column as a DataFrame, 
# not just a Series.
type(df[['status']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
# calling the columns attribute of the DataFrame object df 
# and converting it into a list
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df[['email','keywords','name']]
# Out:
#                     email                                           keywords  \
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3                     NaN  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4                     NaN     COMMUNITY SERVICES, Speakers, Automobile Loans
# 5                     NaN  ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6                     NaN  ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 9                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 10                    NaN  EDUCATION SERVICES, Library, Libraries, Public...
# ...

# %%
# Retrieve the data types of each column in the DataFrame df 
# which can be important for data analysis and manipulation. 
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df1 = pd.read_excel("./Data/LUSID Excel - Setting up your market data.xlsx")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df1[['Unnamed: 8','Unnamed: 9']]
# Out:
#                    Unnamed: 8  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15  "YYYY-MM-DDTHH:MM:SS.00Z"
# 16                        NaN
# 17   2019-04-10T 13:30:45.55Z
# 18                        NaN
# 19  2019-04-10T13:30:45+04:00
# 20                        NaN
# 21  2019-04-10NSingaporeClose
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
#
#                                            Unnamed: 9
# ...

# %%
# DataFrame df2 is being created by reading data from a CSV file located at the given URL
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(df2['Survived'])
# Out:
# pandas.core.series.Series

# %%
df2[['Survived', 'Pclass', 'Name']]
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
# [891 rows x 3 columns]

# %%
df2.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
import lxml
import pandas as pd 

url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
# !pip install lxml

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3 =url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3[['Pos', 'Age', 'Tm']]
# Out:
#     Pos Age   Tm
# 0    PF  24  NYK
# 1    SG  20  MEM
# 2     C  21  OKC
# 3    PF  28  MIN
# 4    SG  29  TOT
# ..   ..  ..  ...
# 670  PF  26  TOT
# 671  PF  26  MIN
# 672  PF  26  BRK
# 673   C  22  CHO
# 674   C  25  BOS
#
# [675 rows x 3 columns]

# %%
df3.to_csv("./Data/players_data.csv",index=False)

# %% [markdown]
# # pandas part 2

# %%
import  pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# The code you provided is using the Pandas library to analyze and display summary statistics of a `DataFrame` named `df.` The `df.describe()` function is being used to generate a table of descriptive statistics for the numerical columns in the DataFrame.
#
# PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare: These are the column names of the DataFrame's attributes that are being summarized.
#
# - count: The number of non-null values in each column.
# - mean: The mean (average) value of each column.
# - std: The standard deviation of each column, which measures the spread or dispersion of the data.
# - min: The minimum value in each column.
# - 25%: The 25th percentile value, which represents the value below which 25% of the data falls.
# - 50%: The 50th percentile value, which is the median value of the data.
# - 75%: The 75th percentile value, representing the value below which 75% of the data falls.
# - max: The maximum value in each column.
#
# This summary gives you a quick overview of the distribution and characteristics of the numerical data in the DataFrame. It can be useful for identifying potential outliers, understanding the range of values, and getting an overall sense of the data's distribution.

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# - The code in the focal cell is checking each column's data type in the DataFrame df and comparing it to the string 'object'.
# - The result is a boolean Series where each column name is associated with either True (if the data type is 'object') or False (if the data type is not 'object').
# - The resulting boolean Series indicates whether each column is of type 'object' or not. This information can be useful for identifying which columns contain categorical or textual data.

# %%
# identify and extract the column names of those columns in the DataFrame 
# where the data type is 'object' (typically representing textual or categorical data).
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
type(df.dtypes[df.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# 1. df.dtypes[df.dtypes == 'object']: This part of the code checks each column's data type in the DataFrame df and compares it to the string 'object'. The result is a boolean Series where each column name is associated with either True (if the data type is 'object', typically representing textual or categorical data) or False (if the data type is not 'object').
# 2. index: The .index part retrieves the index (column names) of the boolean Series obtained in the previous step. This gives us the names of the columns in the DataFrame where the data type is 'object'.
# 3. df[df.dtypes[df.dtypes == 'object'].index]: This part of the code uses the index obtained in step 2 to select only the columns in the DataFrame df where the data type is 'object'.
# 4. describe(): Finally, the .describe() function is applied to the selected categorical columns. This generates a summary table with various statistics for each column.
#
# The statistics include:
#
# - count: The number of non-null values in each column.
# - unique: The number of unique values in each column.
# - top: The most common value in each column.
# - freq: The frequency of the most common value in each column.
#
# The resulting table provides a snapshot of the distribution and characteristics of the categorical data in the DataFrame. This can be useful for understanding the distribution of categories, identifying frequent values, and gaining insights into the categorical data's nature.

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket','Cabin']][4:11:2]
# Out:
#      Ticket Cabin
# 4    373450   NaN
# 6     17463   E46
# 8    347742   NaN
# 10  PP 9549    G6

# %% [markdown]
# - df[['Ticket','Cabin']]: This part selects only the 'Ticket' and 'Cabin' columns from the DataFrame, creating a new DataFrame with only these two columns.
# - [4:11:2]: This slice notation specifies the range of rows to select. It starts from row index 4, goes up to (but does not include) row index 11, and selects every 2nd row within this range.

# %%
#  a new column named 'new_col' is added to the DataFrame df 
# and each element in this column is assigned the value 0
df['new_col'] = 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# The values in "new_col1" are obtained by adding the values from the 'PassengerId' column to the values from the 'Pclass' column element-wise.
df["new_col1"] = df['PassengerId'] + df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %% [markdown]
# - `pd.Categorical(df['Pclass']):` This line of code creates a categorical representation of the 'Pclass' column in the DataFrame 'df'. It converts the column's values into a categorical format. The output is a representation of the 'Pclass' column as categories, showing the values [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3] with a length of 891.
#
# The result also provides some additional information about the categorical data:
# - `Categories (3, int64):` [1, 2, 3]: This line indicates that there are three unique categories in the 'Pclass' column, namely 1, 2, and 3.

# %%
pd.Categorical(df['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
# Show all the unique values present in the 'Cabin' column as an array
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
# select rows where the 'Age' column is greater than 18
df[df['Age'] > 18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Age'] > 18])
# Out:
# 575

# %%
len(df[df['Age'] > 18]) - 891
# Out:
# -316

# %%
# select rows where the 'Fare' column values are greater than 32.204208
df[df['Fare'] > 32.204208]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
# show only the rows where the 'Fare' column has a value of 0
df[df['Fare'] == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
# represents the male passengers
df[df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
# represents the female passangers
df[df['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# show only the rows where the "Pclass" column has a value of 1,
# which corresponds to passengers who were in the 1st class.
# there are other values like 2 for second class and 3 for third class
df[df["Pclass"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Show the passangers who survived the Titanic disaster.
df[df['Survived'] == 1 ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# check if the values in the 'Sex' column of the DataFrame 'df' are equal to the string 'female'
df['Sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
# checks whether the values in the 'Fare' column are greater than 32. 
# The result is a boolean Series of the same length as the DataFrame, 
# where each element represents whether the corresponding row's fare value is greater than 32 or not
df['Fare'] > 32
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
# filter rows where the passenger's sex is female and the fare is greater than 32
df[(df['Sex'] == 'female')  & (df['Fare'] > 32 )]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# displays passengers who are either female or have a fare greater than $32.
df[(df['Sex'] == 'female')  | (df['Fare'] > 32 )]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex'] == 'male')  & (df['Fare'] > 32 )]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# ...

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
# extract the names of passengers who paid the highest fare on the Titanic
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
df[0::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# - The code `df[0::2]` is used to select every other row from the DataFrame df starting from the `first row (index 0).`
# - The number 2 specifies the `step size`, which means it will skip every second row and only include the rows at `even-numbered` indices.

# %%
# retrieves the rows with indices 0 and 1 (the first two rows) and
# extracts the columns 'PassengerId', 'Survived', and 'Pclass' for those rows.
df[['PassengerId','Survived','Pclass']][0:2]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df.iloc[0:2,['PassengerId','Survived','Pclass']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df.iloc[0:2,['PassengerId','Survived','Pclass']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.iloc[0:2,[0,1,2]]

# %% [markdown]
# - `df:` This refers to the DataFrame you're working with.
# - `iloc:` This method is used for integer-based indexing and selection of elements in the DataFrame.
# - `[0:2]:` This specifies the rows you want to select. It's a range from index 0 to 1 (2 is not inclusive), so it includes the first two rows of the DataFrame.
# - `[0,1,2]:` This specifies the columns you want to select. Here, it's selecting columns with indices 0, 1, and 2.

# %%
df.loc[0:2,['PassengerId','Survived','Pclass']]

# %% [markdown]
# - `df:` This is the DataFrame you're working with.
# - `loc:` This indexer is used to select data based on labels.
# - `[0:2]:` This specifies the range of rows to select, from index 0 to 2 (inclusive), so it includes the first three rows of the DataFrame (indices 0, 1, and 2).
# - `['PassengerId', 'Survived', 'Pclass']:` This list specifies the columns you want to select, namely 'PassengerId', 'Survived', and 'Pclass'.

# %% [markdown]
# # pandas part 3

# %%
import pandas as pd

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
s = df['Name'][0:10]

# %% [markdown]
# - `s =:` This assigns the result of the following operation to a variable named s.
# - `df['Name']:` This part selects the column named 'Name' from the DataFrame df.
# - `[0:10]:` This specifies a range from index 0 to 9 (10 is not inclusive), so it includes the first ten elements of the selected 'Name' column.

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
len(s)
# Out:
# 10

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
l = ['sudh','b','c','d','e','f','g','h','i','j']

# %%
s1 =pd.Series(list(s),index = l)

# %% [markdown]
# In the given code:
#
# - A Series named `s1` is created using the `Pandas` library's `pd.Series` constructor.
# - The constructor takes two arguments: `list(s)` and `index=l.`
# - `list(s)` converts the variable s (which contains the first ten elements of the `Name` column from the DataFrame) into a list.
# - `index = l` specifies that the newly created Series should have custom indices provided in the list l.

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
s1
# Out:
# sudh                              Braund, Mr. Owen Harris
# b       Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                                  Heikkinen, Miss. Laina
# d            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                                Allen, Mr. William Henry
# f                                        Moran, Mr. James
# g                                 McCarthy, Mr. Timothy J
# h                          Palsson, Master. Gosta Leonard
# i       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                     Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1["sudh"]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2 = s1.append(s)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\2451741888.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2 = s1.append(s)

# %%
s2
# Out:
# sudh                              Braund, Mr. Owen Harris
# b       Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                                  Heikkinen, Miss. Laina
# d            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                                Allen, Mr. William Henry
# f                                        Moran, Mr. James
# g                                 McCarthy, Mr. Timothy J
# h                          Palsson, Master. Gosta Leonard
# i       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                     Nasser, Mrs. Nicholas (Adele Achem)
# 0                                 Braund, Mr. Owen Harris
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss. Laina
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                                Allen, Mr. William Henry
# 5                                        Moran, Mr. James
# ...

# %%
s2[4]
# Out:
# 'Allen, Mr. William Henry'

# %%
s4 = pd.Series([3,4,5,6,6] , index=[2,4,5,6,1])

# %%
s4
# Out:
# 2    3
# 4    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s5 = pd.Series([34,345,45,45,454] , index=[9,4,5,6,7])

# %%
s5
# Out:
# 9     34
# 4    345
# 5     45
# 6     45
# 7    454
# dtype: int64

# %%
s6 = s4.append(s5)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\937876903.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s6 = s4.append(s5)

# %%
s6
# Out:
# 2      3
# 4      4
# 5      5
# 6      6
# 1      6
# 9     34
# 4    345
# 5     45
# 6     45
# 7    454
# dtype: int64

# %%
# accesses the value at index 4 in the s6 series
s6[4]
# Out:
# 4      4
# 4    345
# dtype: int64

# %%
# selects elements from index 0 to 4 (inclusive) from Series s6
s6[0:5]
# Out:
# 2    3
# 4    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s4
# Out:
# 2    3
# 4    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s5
# Out:
# 9     34
# 4    345
# 5     45
# 6     45
# 7    454
# dtype: int64

# %%
s4*s5
# Out:
# 1       NaN
# 2       NaN
# 4    1380.0
# 5     225.0
# 6     270.0
# 7       NaN
# 9       NaN
# dtype: float64

# %% [markdown]
# This code performs element-wise multiplication between two Pandas Series, s4 and s5. The resulting Series, let's call it result_series, contains the product of corresponding elements from s4 and s5.
#
# Here's the breakdown of the result:
#
# - Index 1: No common index in s4 and s5, so the value is NaN.
# - Index 2: No common index in s4 and s5, so the value is NaN.
# - Index 4: The product of 4 (from s4) and 345 (from s5) is 1380.
# - Index 5: The product of 5 (from s4) and 45 (from s5) is 225.
# - Index 6: The product of 6 (from s4) and 45 (from s5) is 270.
# - Index 7: No value at index 7 in s4, so the value is NaN.
# - Index 9: No value at index 9 in s4, so the value is NaN.
# - The result_series is of type float64 since it contains NaN values.

# %%
s4+s5
# Out:
# 1      NaN
# 2      NaN
# 4    349.0
# 5     50.0
# 6     51.0
# 7      NaN
# 9      NaN
# dtype: float64

# %% [markdown]
# In this code, the element-wise addition operation is performed between two Pandas Series, s4 and s5. The resulting Series, let's call it result_series, contains the sum of corresponding elements from s4 and s5.
#
# Here's the breakdown of the result:
#
# - Index 1: No common index in s4 and s5, so the value is NaN.
# - Index 2: No common index in s4 and s5, so the value is NaN.
# - Index 4: The sum of 4 (from s4) and 345 (from s5) is 349.
# - Index 5: The sum of 5 (from s4) and 45 (from s5) is 50.
# - Index 6: The sum of 6 (from s4) and 45 (from s5) is 51.
# - Index 7: No value at index 7 in s4, so the value is NaN.
# - Index 9: No value at index 9 in s4, so the value is NaN.

# %% [markdown]
# # pandas part 4

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId', axis=1, inplace=True)

# %% [markdown]
# In this code, the `df DataFrame` is being modified. Specifically, the `drop()` method is used to remove a column named `PassengerId` from the DataFrame. The parameters used in this method are:
#
# - `PassengerId:` This is the label of the column you want to remove.
# - `axis=1:` This indicates that you are specifying a column to drop (as opposed to a row), so it's along the horizontal axis.
# - `inplace=True:` This parameter is optional. When set to `True`, it means that the modification will be done directly on the `DataFrame (df)` without creating a new DataFrame. If set to `False`, a new `modifie`d DataFrame would be returned, leaving the `original` DataFrame unchanged.

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3, inplace=True)

# %% [markdown]
# In this code, a modification is being made to the `DataFrame (df).` The `drop()` method is being used to remove a row with index 3 from the DataFrame. The parameters used in this method are:
#
# - `3:` This is the index label of the row you want to remove.
# - `inplace=True:` This optional parameter, when set to `True`, indicates that the modification will be applied directly to the `original` DataFrame (df) without creating a new DataFrame. If set to `False`, a new `modified` DataFrame would be returned, leaving the `original` DataFrame unchanged.

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Name", inplace=True)

# %% [markdown]
# In this code, the `set_index()` method is being used to modify the DataFrame df. Specifically, it's changing the `index` of the DataFrame to be based on the values in the `Name` column. Here's a breakdown of the parameters used:
#
# - `Name:` This is the label of the column that will be used as the new index for the DataFrame.
# - `inplace=True:` This optional parameter, when set to `True`, indicates that the modification will be applied directly to the `original` DataFrame (df) without creating a new DataFrame. If set to `False`, a new `modified` DataFrame would be returned, leaving the `original` DataFrame unchanged.
#
# This change means that instead of using the default numeric row indices, the DataFrame will now be indexed by the values in the `Name` column. This can be useful for quickly accessing rows based on their associated names. Just be cautious, as setting an index can affect the performance of certain operations on the DataFrame.

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
# eset the index of the DataFrame, reverting it back to the default numeric row indices.
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# initializing a dictionary d with three keys 'key1', 'key2', and 'key3'. 
# Each key corresponds to a list of values.
d = {'key1':[3,4,5,6,7],
     'key2':[5,6,7,8,6],
     'key3':[4,5,6,7,8]
}

# %%
# Creating a dataframe
# the keys become column headers 
# the lists of values become the data in those columns.
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
df1 = pd.read_csv('./Data/taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# remove rows with missing or NaN (Not a Number) values from the DataFrame. 
# It does not modify the DataFrame in place by default, 
# meaning it returns a new DataFrame with the specified rows removed. 
# if you want to modify the original DataFrame in place, you need to set the inplace parameter to True.
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
# modified dataframe that has no NAN values in any column
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
# it will remove any column where at least one cell has a missing or NaN value.
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2 = pd.read_csv('./Data/taxonomy.csv')

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# it will remove any column where at least one cell has a missing or NaN value.
df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
# fill missing or NaN values in the DataFrame with a specified value "sudh" 
df2.fillna("sudh")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      sudh                  sudh
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# allows you to group data based on one or more columns.
# In this case, the data is being grouped by the unique values in the 'Survived' column.
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %% [markdown]
# The `sum()` function calculates the sum of each numeric column within each group. In this case, it's summing up the values for `Pclass`, `Age`, `SibSp`, `Parch`, and `Fare` columns for each group of `Survived' (0 or 1).` The resulting output is a summarized table where each row corresponds to a `Survived` group and columns show the summed values for each numeric attribute.

# %%
g.mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %% [markdown]
# `mean()` function calculates the `mean (average)` of each numeric column within each group. The resulting output is a table that displays the `average` values of `Pclass`, `Age`, `SibSp`, `Parch`, and `Fare` columns for each group of `Survived' (0 or 1).` Each row corresponds to a `Survived` group, and the columns show the `average` values of the respective numeric attributes.

# %%
# the data is grouped by the 'Pclass' column, 
# which likely represents passenger class in some kind of dataset 
# (e.g., from Titanic dataset where 'Pclass' might be 1, 2, or 3).
g1 = df.groupby('Pclass')

# %%
g1.sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
# The max() function is applied to this grouped data, calculating the maximum value for each numeric column within each group. 
g1.max()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\1105602347.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  Survived   Sex   Age  SibSp  Parch  \
# Pclass
# 1          Young, Miss. Marie Grice         1  male  80.0      3      4
# 2         del Carlo, Mr. Sebastiano         1  male  70.0      3      3
# 3       van Melkebeke, Mr. Philemon         1  male  74.0      8      6
#
#             Ticket      Fare
# Pclass
# 1        WE/P 5735  512.3292
# 2        W/C 14208   73.5000
# 3       W./C. 6609   69.5500

# %%
# The .T at the end transposes the resulting DataFrame to switch rows and columns.
g1.max().T
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\3949790912.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
g1.max().transpose()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df5 = df[['Name', 'Survived', 'Pclass']][0:5]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6 = df[['Name', 'Survived', 'Pclass']][5:10]

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
# combine two or more DataFrames along a specified axis (default is 0, which means along rows).
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
# The axis=1 parameter specifies that the concatenation should be done along columns. 
df7 = pd.concat([df5,df6],axis=1)

# %%
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3                           Allen, Mr. William Henry       0.0     3.0
# 4                                   Moran, Mr. James       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %%
df7.fillna('sudh')
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                               sudh     sudh   sudh
# 6                                               sudh     sudh   sudh
# 7                                               sudh     sudh   sudh
# 8                                               sudh     sudh   sudh
# 9                                               sudh     sudh   sudh
#
#                                                 Name Survived Pclass
# 0                                               sudh     sudh   sudh
# 1                                               sudh     sudh   sudh
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2 = pd.DataFrame({'key1':[1,2,45,6,67],
                      'key4':[56,5,6,7,8],
                      'key5':[3,56,5,6,6]})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %% [markdown]
# - The `pd.merge()` function combines the two DataFrames by matching the values in the columns that have the same names, which are `key1` in this case.
# - The resulting merged DataFrame displays the values from both data1 and data2 based on the matching values in the `key1` column.

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %% [markdown]
# In the given code, the `pd.merge(data1, data2, how='left')` statement is used to merge two DataFrames, data1 and data2, using a left join. Here's a breakdown of what's happening:
#
# - `pd.merge:` This function is from the Pandas library and is used to combine two DataFrames based on specified columns.
# - `data1 and data2:` These are the two DataFrames that are being merged.
# - `how='left':` This parameter specifies the type of join to perform. In this case, a left join is being used. A left join includes all rows from the left DataFrame (data1) and the matching rows from the right DataFrame (data2) based on the matching values in the columns that have the same names, which are `key1` in this case.. If there are no matches in data2, the corresponding columns will have NaN (Not a Number) values.

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %% [markdown]
# In the given code, the `pd.merge(data1, data2, how='right')` statement is used to merge two DataFrames, data1 and data2, using a left join. Here's a breakdown of what's happening:
#
# - `pd.merge:` This function is from the Pandas library and is used to combine two DataFrames based on specified columns.
# - `data1 and data2:` These are the two DataFrames that are being merged.
# - `how='right':` This parameter specifies the type of join to perform. In this case, a right join is being used. A right join includes all rows from the right DataFrame (data2) and the matching rows from the left DataFrame (data1) based on the matching values in the columns that have the same names, which are `key1` in this case.. If there are no matches in data1, the corresponding columns will have NaN (Not a Number) values.

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(data1,data2,how = 'outer',on = 'key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %% [markdown]
# `how='outer':` This parameter specifies the type of join to perform. In this case, an outer join is being used. An outer join includes all rows from both DataFrames (data1 and data2) and includes matching rows based on the values in the specified columns (key1 in this case). If there are no matches in either DataFrame for a particular value of key1, the corresponding columns will have NaN (Not a Number) values.

# %%
pd.merge(data1,data2,how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %% [markdown]
# In this code, the `pd.merge(data1, data2, how='cross')` statement is used to merge two DataFrames, data1 and data2, using a `cross join.` A cross join, also known as a `Cartesian join`, combines every row from the first DataFrame with every row from the second DataFrame, resulting in a combination of all possible pairs of rows. This type of join doesn't require any matching columns, unlike other joins that merge based on specified columns.

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                     index = ['a','b','c','d','e'])

# %%
data2 = pd.DataFrame({'key11':[1,2,4,5,6],
                      'key22':[4,5,6,7,8],
                      'key33':[3,4,5,6,6]},
                      index=['a','b','h','i','j'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# j      6      8      6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data1.join(data2,how='left')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %% [markdown]
# - The resulting DataFrame displays the values from both `data1` and `data2` for the matching `index` values. The columns are concatenated, resulting in a wider DataFrame with all the columns from both DataFrames.
# - Only the rows corresponding to the indices from `data1` will be considered like `left join` and `non-matching index` values of the DataFrame `data2` results in NaN (Not a Number) values in the cells.

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1      4      3
# b   2.0   5.0   4.0      2      5      4
# h   NaN   NaN   NaN      4      6      5
# i   NaN   NaN   NaN      5      7      6
# j   NaN   NaN   NaN      6      8      6

# %% [markdown]
# - The resulting DataFrame displays the values from both `data1` and `data2` for the matching `index` values. The columns are concatenated, resulting in a wider DataFrame with all the columns from both DataFrames.
# - Only the rows corresponding to the indices from `data2` will be considered like `right join` and `non-matching index` values of the DataFrame `data1` results in NaN (Not a Number) values in the cells.

# %%
# An inner join retains only the rows with matching indices in both DataFrames and combines their columns.
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
# combines the data from both DataFrames based on their index values, 
# including all the rows from both DataFrames and filling in NaN (Not a Number) values
# where there are no matches in indices.
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    5.0
# i   NaN   NaN   NaN    5.0    7.0    6.0
# j   NaN   NaN   NaN    6.0    8.0    6.0

# %%
# each row from the first dataset is combined with every row from the second dataset, 
# resulting in a Cartesian product of the two datasets.
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      4      6      5
# 3      1     4     3      5      7      6
# 4      1     4     3      6      8      6
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4      4      6      5
# 8      2     5     4      5      7      6
# 9      2     5     4      6      8      6
# 10     4     6     5      1      4      3
# 11     4     6     5      2      5      4
# 12     4     6     5      4      6      5
# 13     4     6     5      5      7      6
# 14     4     6     5      6      8      6
# 15     5     7     6      1      4      3
# 16     5     7     6      2      5      4
# 17     5     7     6      4      6      5
# 18     5     7     6      5      7      6
# 19     5     7     6      6      8      6
# 20     6     8     6      1      4      3
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# lambda function takes an input x (which represents each individual value in the 'Fare' column),
# and multiplies it by 80 to get the fare values converted into Indian rupees
# Also the changed column 'Fare_INR' is added to data frame
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
# converts the fare value from Euros to Indian Rupees.
def euro_inr(x):
    return x*80

# euro_inr function to each value in the 'Fare' column of the DataFrame 'df'.
# The resulting values are assigned to the new 'Fare_INR' column in the same DataFrame.
df['Fare_INR'] = df['Fare'].apply(euro_inr)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR  name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# ...

# %%
def class_fare(x):
    if x<10 :
        return "cheap"
    elif x>=10 and x<20:
        return 'mid'
    else :
        return 'high'

# %%
df['class_fare'] = df['Fare'].apply(cat_fare)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 df['class_fare'] = df['Fare'].apply(cat_fare)
#
# NameError: name 'cat_fare' is not defined

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %% [markdown]
# # pandas part 5

# %%
import pandas as pd

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       "c":["sudh","krish","hitesh","navin"]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   krish
# 3  6  hitesh
# 4  7   navin

# %%
df = df.reset_index()

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       "c":["sudh" , "krish","hitesh","navin"]}

df1 = pd.DataFrame(data,index = ['a','b','c','d'])

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1.reindex(['b','c','d','a'])
# Out:
#    a  b       c
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin
# a  1  4    sudh

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
# This loop iterates over the rows of the DataFrame df1 using the iterrows() function. 
# In each iteration, it provides two variables, i which represents the index of the row,
# and j which represents the row itself as a Series. 
# The code then prints out the content of each row.
for i,j in df1.iterrows():
    print( j)
# Out:
# a       1
# b       4
# c    sudh
# Name: a, dtype: object
# a        2
# b        5
# c    krish
# Name: b, dtype: object
# a         3
# b         6
# c    hitesh
# Name: c, dtype: object
# a        4
# b        7
# c    navin
# Name: d, dtype: object

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
# The loop iterates through each column in the DataFrame df1.
# col_name represents the name of the column, and column represents the content of that column.
for col_name, column in df1.iteritems():
    # Within each iteration, it prints the column name and the content of the column.
    print(col_name, column)
# Out:
# a a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64
# b a    4
# b    5
# c    6
# d    7
# Name: b, dtype: int64
# c a      sudh
# b     krish
# c    hitesh
# d     navin
# Name: c, dtype: object
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4144\2719594029.py:3: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, column in df1.iteritems():

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
# This line is extracting the values from the 'a' column of the DataFrame df 
# and converting them into a Python list.
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
# extracting the values from the 'a' column and putting them into a list.
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
# Define a function named 'test' that takes a parameter 'x'
# and returns the sum of the elements in 'x'
def test(x):
    return x.sum()

# Apply the 'test' function along the columns (axis=0) of the DataFrame 'df1'
# This will calculate the sum of elements in each column
df1.apply(test, axis=0)
# Out:
# a                      10
# b                      22
# c    sudhkrishhiteshnavin
# dtype: object

# %%
# Select specific columns 'a' and 'b' and create a new DataFrame 'df2'
df2 = df1[['a', 'b']]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
# Apply a lambda function to each element of DataFrame 'df2', squaring each element
df2.applymap(lambda x : x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
# Sorting the DataFrame 'df' based on the values in the 'c' column.
# This operation rearranges the rows in ascending order according to the values in the 'c' column.
df.sort_values('c')
# Out:
#    a  b       c
# 2  3  6  hitesh
# 1  2  5   krish
# 3  4  7   navin
# 0  1  4    sudh

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
# Sorting the DataFrame 'df' based on the index labels.
# The 'ascending' parameter is set to False, so the index labels will be sorted in descending order.
df.sort_index(ascending = False)
# Out:
#    a  b       c
# 3  4  7   navin
# 2  3  6  hitesh
# 1  2  5   krish
# 0  1  4    sudh

# %%
# Set an option to display wide column content
pd.set_option("display.max_colwidth" ,1000)
# Create a DataFrame 'df3' with a single column 'Desc' containing a description
df3 = pd.DataFrame({"Desc" :["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language."] })

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# ...

# %%
# Set an option to display wide column content
pd.set_option("display.max_colwidth" ,1000)
# Create a DataFrame 'df3' with a single column 'Desc' containing descriptions
df3 = pd.DataFrame({"Desc" :["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language." , "my name is sudh" ,"i use to teach data science "] })

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# ...

# %%
# Calculate the length of each description and add a new column 'len' to the DataFrame
df3['len'] = df3['Desc'].apply(len)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# ...

# %%
# Define a string containing a sentence
t ="i use to teach data science	"
# Split the string into words using the split() function
words = t.split()
# Calculate the number of words in the string by getting the length of the 'words' list
num_words = len(words)
# Print the calculated number of words
print("The number of words in the sentence is:", num_words)
# Out:
# The number of words in the sentence is: 6

# %%
# Calculate the number of words in each description and add a new column 'word_count' to the DataFrame
df3['word_count'] = df3['Desc'].apply(lambda x :len(x.split()))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# ...

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df['a'][0]
# Out:
# 1

# %%
df['a'][2]
# Out:
# 3

# %%
# calculate the average of the numerical values in the 'a' column.
df['a'].mean()
# Out:
# 2.5

# %%
# calculate the median (middle) value of the numerical data in the specified column.
df['a'].median()
# Out:
# 2.5

# %%
# indicates that the values 1, 2, 3, and 4 are all modes of the 'a' column, 
# meaning they are the most frequently occurring values in that column.
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
# calculates the standard deviation of the numerical values in the 'a' column of the DataFrame 'df'.
# Standard deviation is a measure of the amount of variation or dispersion in a set of values.
df['a'].std()
# Out:
# 1.2909944487358056

# %%
df['a'].sum()
# Out:
# 10

# %%
df['a'].min()
# Out:
# 1

# %%
df['a'].max()
# Out:
# 4

# %%
# calculate the variance of the numerical values in the 'a' column of the DataFrame 'df'.
# Variance is a statistical measure that describes how much the values in a dataset differ from the mean (average) of that dataset.
# It's used to understand the spread or dispersion of the data points.
df['a'].var()
# Out:
# 1.6666666666666667

# %%
#Python Pandas - Window Functions
df4 = pd.DataFrame({'a' : [3,4,5,2,1,3,4,5,6]})

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].rolling(window=1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %% [markdown]
# - `df4['a']` accesses the column labeled 'a' in the DataFrame df4.
# - `rolling(window=1)` applies a rolling window of size 1 to the values in the 'a' column. This means it will consider each value individually.
# - `mean()` calculates the mean (average) value within each rolling window.

# %%
# consider each value along with the previous value within a window of size 2
# calculates the mean (average) value within each rolling window of size 2.
df4['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
# considers each value along with the two previous values within a window of size 3.
# calculates the mean (average) value within each rolling window of size 3.
df4['a'].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
# the previous values of index 0 is NAN.
# Sum of NAN with any other values is NAN.
# That's why in case of mean also, we get NAN for first two indices.
df4['a'].rolling(window=3).sum()
# Out:
# 0     NaN
# 1     NaN
# 2    12.0
# 3    11.0
# 4     8.0
# 5     6.0
# 6     8.0
# 7    12.0
# 8    15.0
# Name: a, dtype: float64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
# the previous values of index 0 is NAN.
# min of three values will be NAN if one of the values is NAN
df4['a'].rolling(window=3).min()
# Out:
# 0    NaN
# 1    NaN
# 2    3.0
# 3    2.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    3.0
# 8    4.0
# Name: a, dtype: float64

# %%
# the previous values of index 0 is NAN.
# max of three values will be NAN if one of the values is NAN
df4['a'].rolling(window=3).max()
# Out:
# 0    NaN
# 1    NaN
# 2    5.0
# 3    5.0
# 4    5.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
# calculates the cumulative sum of the values in the 'a' column, 
# where each element is the sum of all previous elements including itself.
df4['a'].cumsum()
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
# generate a sequence of dates within a specified range.
date = pd.date_range(start='2023-04-23' , end = '2023-06-23')

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
# ...

# %%
# This DataFrame contains a single column labeled 'date'. 
# The values in this column are generated using the pd.date_range() function
df_date = pd.DataFrame({'date':date})

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df7 = pd.DataFrame({"date" : ['2023-06-23' , '2023-06-22','2023-06-20']})

# %%
df7
# Out:
#          date
# 0  2023-06-23
# 1  2023-06-22
# 2  2023-06-20

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
# convert the 'date' column in the df7 DataFrame to datetime format using the pd.to_datetime() function
df7['updated_date'] = pd.to_datetime(df7['date'])

# %%
df7
# Out:
#          date updated_date
# 0  2023-06-23   2023-06-23
# 1  2023-06-22   2023-06-22
# 2  2023-06-20   2023-06-20

# %%
df7.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df7['year'] = df7['updated_date'].dt.year

# %%
df7
# Out:
#          date updated_date  year
# 0  2023-06-23   2023-06-23  2023
# 1  2023-06-22   2023-06-22  2023
# 2  2023-06-20   2023-06-20  2023

# %%
df7['day'] = df7['updated_date'].dt.day

# %%
df7
# Out:
#          date updated_date  year  day
# 0  2023-06-23   2023-06-23  2023   23
# 1  2023-06-22   2023-06-22  2023   22
# 2  2023-06-20   2023-06-20  2023   20

# %%
df7['month'] = df7['updated_date'].dt.month

# %%
df7
# Out:
#          date updated_date  year  day  month
# 0  2023-06-23   2023-06-23  2023   23      6
# 1  2023-06-22   2023-06-22  2023   22      6
# 2  2023-06-20   2023-06-20  2023   20      6

# %%
#Python Pandas –Time Delta

# %%
pd.Timedelta(days= 1,hours = 5 ,minutes = 45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
# convert the given string '2023-06-20' into a pandas datetime object. 
# This function converts various input types into a standardized datetime format 
# that allows for convenient manipulation of dates and times.
dt = pd.to_datetime('2023-06-20')

# %%
td = pd.Timedelta(days = 1 )

# %%
# a new timestamp representing the date and time 
# that is 1 day after the given date (dt).
dt + td
# Out:
# Timestamp('2023-06-21 00:00:00')

# %%
#Python Pandas - Categorical Data

data = ["sudh" , "krish" , "hitesh" , "navin","sudh" ,"sudh" ]

# %%
# creates a Pandas Categorical object named cat from the data list. 
# Categorical data is used to represent data with a limited, fixed set of values, 
# and this can be useful for optimizing memory usage and performing certain types of analysis.
cat = pd.Categorical(data)

# %%
cat
# Out:
# ['sudh', 'krish', 'hitesh', 'navin', 'sudh', 'sudh']
# Categories (4, object): ['hitesh', 'krish', 'navin', 'sudh']

# %%
# counts the occurrences of each unique value in the Categorical object 
# and returns a new Pandas Series with the counts as values and the unique values as the index.
cat.value_counts()
# Out:
# hitesh    1
# krish     1
# navin     1
# sudh      3
# dtype: int64

# %%
#Python Pandas – Visualization

# %%
d = pd.Series([1,2,3,3,5,6,6,8])
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
# d.plot() is used to create a plot of the data in the d Series.
# generates a visualization of the data using the default line plot
d.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'a':[3,4,5,6,7],
                  'b':[4,5,6,7,8]})

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
# the values from the 'a' column will be used for the x-axis, 
# and the values from the 'b' column will be used for the y-axis in the plot.
df.plot(x= 'a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x= 'a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# - A `scatter plot` is a type of data visualization that displays individual data points as dots on a two-dimensional plane.
# - Each dot represents a single observation in your dataset.
# - Scatter plots are commonly used to visualize the relationship between two variables and to identify patterns, trends, or correlations between them.
# - The position of each dot on the plot is determined by the values of the two variables being compared.
# - This type of plot is particularly useful for identifying `clusters`, `outliers`, and the overall distribution of the data points.

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
d = pd.Series([1,2,3,3,5,6,6,8])
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
# create a pie chart visualization of the data in the Series d. 
# A pie chart is a circular statistical graphic divided into slices to represent numerical proportions.
d.plot.pie()
# Out:
# <Axes: >

# %% [markdown]
# - A `pie plot`, also known as a `pie chart`, is a circular statistical graphic that is divided into slices to represent numerical proportions or percentages. - Each slice of the pie chart represents a portion of the whole data set, and the size of each slice is proportional to the value it represents in relation to the total.
# - In the given context, you've already used the `d.plot.pie()` function to create a pie chart visualization of the data in the Series d.
# - This function generates a pie chart where each unique value in the Series is represented by a slice of the pie, and the size of each slice corresponds to the `frequency` of that value in the data.
